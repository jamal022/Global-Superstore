# %%
# import necessary libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\gamal\Downloads\Python Bootcamp For Data Science and ML\Pandas_Project_Session\data\global_superstore\global_superstore_2016.csv',encoding='latin1')
df.head()
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# 0  ...  TEC-PH-5816  Technology       Phones
# 1  ...  FUR-CH-5379   Furniture       Chairs
# 2  ...  TEC-PH-5356  Technology       Phones
# 3  ...  TEC-PH-5267  Technology       Phones
# 4  ...  TEC-CO-6011  Technology      Copiers
#
#                                 Product Name       Sales Quantity Discount  \
# 0                           Samsung Convoy 3    $221.98         2      0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40         9      0.1
# 2          Nokia Smart Phone, with Caller ID  $5,175.17         9      0.1
# 3             Motorola Smart Phone, Cordless  $2,892.51         5      0.1
# 4             Sharp Wireless Fax, High-Speed  $2,832.96         8      0.0
#
#       Profit Shipping Cost  Order Priority
# 0    $62.15          40.77            High
# 1  ($288.77)        923.63        Critical
# 2   $919.97         915.49          Medium
# 3   ($96.54)        910.16          Medium
# 4   $311.52         903.04        Critical
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Postal Code       float64
# City               object
# State              object
# Country            object
# Region             object
# Market             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales              object
# Quantity            int64
# Discount          float64
# Profit             object
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
# here as we can see in column [Order Date , Ship Date ] in Object data type which can be in datetime datatype for better proccessing
# So we are going to create a function to do that task for us
def convert_to_datetime(df,feature):
    df[feature] = pd.to_datetime(df[feature])

# %%
date_list = ['Order Date','Ship Date']

for feature in date_list:
    convert_to_datetime(df,feature)

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                     object
# Quantity                   int64
# Discount                 float64
# Profit                    object
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
# After convertig into Datetime objects, convert into a Series objects
Order_date = pd.Series(df['Order Date'], name='Order_Date')
Ship_date = pd.Series(df['Ship Date'], name='Ship_Date')

# %%
df.columns.values
# Out:
# array(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'], dtype=object)

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# 0  ...  TEC-PH-5816  Technology       Phones
# 1  ...  FUR-CH-5379   Furniture       Chairs
# 2  ...  TEC-PH-5356  Technology       Phones
# 3  ...  TEC-PH-5267  Technology       Phones
# 4  ...  TEC-CO-6011  Technology      Copiers
#
#                                 Product Name       Sales Quantity Discount  \
# 0                           Samsung Convoy 3    $221.98         2      0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40         9      0.1
# 2          Nokia Smart Phone, with Caller ID  $5,175.17         9      0.1
# 3             Motorola Smart Phone, Cordless  $2,892.51         5      0.1
# 4             Sharp Wireless Fax, High-Speed  $2,832.96         8      0.0
#
#       Profit Shipping Cost  Order Priority
# 0    $62.15          40.77            High
# 1  ($288.77)        923.63        Critical
# 2   $919.97         915.49          Medium
# 3   ($96.54)        910.16          Medium
# 4   $311.52         903.04        Critical
#
# [5 rows x 24 columns]

# %%
# Now Let's Drop unwanted columns 
df.drop(columns=['Row ID', 'Order Date', 'Ship Date', 'Customer ID', 'Postal Code'], inplace=True)
df.head(n=2)
# Out:
#                    Order ID     Ship Mode  Customer Name    Segment  \
# 0  CA-2014-AB10015140-41954   First Class  Aaron Bergman   Consumer
# 1    IN-2014-JR162107-41675  Second Class  Justin Ritter  Corporate
#
#             City            State        Country      Region        Market  \
# 0  Oklahoma City         Oklahoma  United States  Central US          USCA
# 1     Wollongong  New South Wales      Australia     Oceania  Asia Pacific
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name       Sales  Quantity  Discount  \
# 0                           Samsung Convoy 3    $221.98          2       0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40          9       0.1
#
#       Profit  Shipping Cost Order Priority
# 0    $62.15           40.77           High
# 1  ($288.77)         923.63       Critical

# %%
# Concat new columns to the original data
global_data = pd.concat([df, Order_date, Ship_date], axis=1)
global_data.head(n=2)
# Out:
#                    Order ID     Ship Mode  Customer Name    Segment  \
# 0  CA-2014-AB10015140-41954   First Class  Aaron Bergman   Consumer
# 1    IN-2014-JR162107-41675  Second Class  Justin Ritter  Corporate
#
#             City            State        Country      Region        Market  \
# 0  Oklahoma City         Oklahoma  United States  Central US          USCA
# 1     Wollongong  New South Wales      Australia     Oceania  Asia Pacific
#
#     Product ID  ... Sub-Category                               Product Name  \
# 0  TEC-PH-5816  ...       Phones                           Samsung Convoy 3
# 1  FUR-CH-5379  ...       Chairs  Novimex Executive Leather Armchair, Black
#
#         Sales Quantity  Discount     Profit Shipping Cost  Order Priority  \
# 0    $221.98         2       0.0    $62.15          40.77            High
# 1  $3,709.40         9       0.1  ($288.77)        923.63        Critical
#
#   Order_Date  Ship_Date
# 0 2014-11-11 2014-11-13
# 1 2014-02-05 2014-02-07
#
# [2 rows x 21 columns]

# %%
# Reindex the data to be in the original order
global_data = global_data.reindex(columns=['Order ID', 'Order_Date', 'Ship_Date', 'Ship Mode','Customer Name', 'Segment', 'Postal Code', 'City','State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
       'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority'])

# %%
global_data.head()
# Out:
#                    Order ID Order_Date  Ship_Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#       Customer Name      Segment  Postal Code           City            State  \
# 0     Aaron Bergman     Consumer          NaN  Oklahoma City         Oklahoma
# 1     Justin Ritter    Corporate          NaN     Wollongong  New South Wales
# 2      Craig Reiter     Consumer          NaN       Brisbane       Queensland
# 3  Katherine Murray  Home Office          NaN         Berlin           Berlin
# 4       Rick Hansen     Consumer          NaN          Dakar            Dakar
#
#          Country  ...   Product ID    Category Sub-Category  \
# 0  United States  ...  TEC-PH-5816  Technology       Phones
# 1      Australia  ...  FUR-CH-5379   Furniture       Chairs
# 2      Australia  ...  TEC-PH-5356  Technology       Phones
# 3        Germany  ...  TEC-PH-5267  Technology       Phones
# 4        Senegal  ...  TEC-CO-6011  Technology      Copiers
#
#                                 Product Name       Sales Quantity Discount  \
# 0                           Samsung Convoy 3    $221.98         2      0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40         9      0.1
# 2          Nokia Smart Phone, with Caller ID  $5,175.17         9      0.1
# 3             Motorola Smart Phone, Cordless  $2,892.51         5      0.1
# 4             Sharp Wireless Fax, High-Speed  $2,832.96         8      0.0
#
#       Profit  Shipping Cost Order Priority
# 0    $62.15           40.77           High
# 1  ($288.77)         923.63       Critical
# 2   $919.97          915.49         Medium
# 3   ($96.54)         910.16         Medium
# 4   $311.52          903.04       Critical
#
# [5 rows x 22 columns]

# %%
global_data.columns
# Out:
# Index(['Order ID', 'Order_Date', 'Ship_Date', 'Ship Mode', 'Customer Name',
#        'Segment', 'Postal Code', 'City', 'State', 'Country', 'Region',
#        'Market', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost',
#        'Order Priority'],
#       dtype='object')

# %%
global_data['Shipping Cost'].astype(int)[:10]
# Out:
# 0     40
# 1    923
# 2    915
# 3    910
# 4    903
# 5    897
# 6    894
# 7    878
# 8     25
# 9     11
# Name: Shipping Cost, dtype: int32

# %%
# check whether all the values of columns 'Sales' & 'Profit' contains $ symbol or not

# %%
if global_data['Sales'].str.contains('$').any():
    print("Yes: $ Symbol is Present in The Column Sales")
# Out:
# Yes: $ Symbol is Present in The Column Sales

# %%
if global_data['Profit'].str.contains('$').any():
    print("Yes: $ Symbol is Present in The Column Profit")
# Out:
# Yes: $ Symbol is Present in The Column Profit

# %%
if global_data['Sales'].str.contains(',').any():
    print("Yes: , Symbol is Present in The Column Profit")
# Out:
# Yes: , Symbol is Present in The Column Profit

# %%
global_data['Sales'] = global_data['Sales'].str.replace('$', '', regex=True)
global_data['Sales'][:10]
# Out:
# 0      221.98
# 1    3,709.40
# 2    5,175.17
# 3    2,892.51
# 4    2,832.96
# 5    2,862.68
# 6    1,822.08
# 7    5,244.84
# 8      341.96
# 9       48.71
# Name: Sales, dtype: object

# %%
global_data['Sales'] = global_data['Sales'].str.replace(',', '', regex=True)
global_data['Sales'][:10]
# Out:
# 0     221.98
# 1    3709.40
# 2    5175.17
# 3    2892.51
# 4    2832.96
# 5    2862.68
# 6    1822.08
# 7    5244.84
# 8     341.96
# 9      48.71
# Name: Sales, dtype: object

# %%
global_data['Profit'] = global_data['Profit'].str.replace('$', '', regex=True)
global_data['Profit'][:10]
# Out:
# 0      62.15
# 1    (288.77)
# 2     919.97
# 3     (96.54)
# 4     311.52
# 5     763.28
# 6     564.84
# 7     996.48
# 8      54.71
# 9       5.48
# Name: Profit, dtype: object

# %%
global_data['Profit'] = global_data['Profit'].str.replace('(', '', regex=True)
global_data['Profit'][:10]
# Out:
# 0     62.15
# 1    288.77)
# 2    919.97
# 3     96.54)
# 4    311.52
# 5    763.28
# 6    564.84
# 7    996.48
# 8     54.71
# 9      5.48
# Name: Profit, dtype: object

# %%
global_data['Profit'] = global_data['Profit'].str.replace(')', '', regex=True)
global_data['Profit'][:20]
# Out:
# 0        62.15
# 1        288.77
# 2       919.97
# 3         96.54
# 4       311.52
# 5       763.28
# 6       564.84
# 7       996.48
# 8        54.71
# 9         5.48
# 10        4.66
# 11      647.55
# 12    1,151.40
# 13      622.02
# 14    1,036.08
# 15      186.95
# 16         2.52
# 17    3,979.08
# 18       28.40
# 19      818.28
# Name: Profit, dtype: object

# %%
global_data['Profit'] = global_data['Profit'].str.replace(',', '', regex=True)
global_data['Profit'][:20]
# Out:
# 0       62.15
# 1       288.77
# 2      919.97
# 3        96.54
# 4      311.52
# 5      763.28
# 6      564.84
# 7      996.48
# 8       54.71
# 9        5.48
# 10       4.66
# 11     647.55
# 12    1151.40
# 13     622.02
# 14    1036.08
# 15     186.95
# 16        2.52
# 17    3979.08
# 18      28.40
# 19     818.28
# Name: Profit, dtype: object

# %%
# After removing the symbols, convert them to a numeric columns and of type 'int'

# %%
global_data['Profit'] = pd.to_numeric(global_data['Profit'], downcast='signed')
global_data['Profit'][:10]
# Out:
# 0     62.15
# 1    288.77
# 2    919.97
# 3     96.54
# 4    311.52
# 5    763.28
# 6    564.84
# 7    996.48
# 8     54.71
# 9      5.48
# Name: Profit, dtype: float64

# %%
global_data['Sales'] = pd.to_numeric(global_data['Sales'], downcast='integer')
global_data['Sales'][:10]
# Out:
# 0     221.98
# 1    3709.40
# 2    5175.17
# 3    2892.51
# 4    2832.96
# 5    2862.68
# 6    1822.08
# 7    5244.84
# 8     341.96
# 9      48.71
# Name: Sales, dtype: float64

# %%
global_data['Profit'] = global_data['Profit'].astype(int)
global_data['Sales'] = global_data['Sales'].astype(int)

# %%
global_data.dtypes
# Out:
# Order ID                  object
# Order_Date        datetime64[ns]
# Ship_Date         datetime64[ns]
# Ship Mode                 object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                      int32
# Quantity                   int64
# Discount                 float64
# Profit                     int32
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
# 1st: Total, how many orders have cross the shipping cost of 500?

# %%
cond1  = (global_data['Shipping Cost'] > 500.00)

# %%
shipping_g500 = global_data[cond1]
shipping_g500.head()
# Out:
#                   Order ID Order_Date  Ship_Date     Ship Mode  \
# 1   IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3  ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4  SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
# 5   IN-2014-JM156557-41818 2014-06-28 2014-07-01  Second Class
#
#       Customer Name      Segment  Postal Code        City            State  \
# 1     Justin Ritter    Corporate          NaN  Wollongong  New South Wales
# 2      Craig Reiter     Consumer          NaN    Brisbane       Queensland
# 3  Katherine Murray  Home Office          NaN      Berlin           Berlin
# 4       Rick Hansen     Consumer          NaN       Dakar            Dakar
# 5       Jim Mitchum    Corporate          NaN      Sydney  New South Wales
#
#      Country  ...   Product ID    Category Sub-Category  \
# 1  Australia  ...  FUR-CH-5379   Furniture       Chairs
# 2  Australia  ...  TEC-PH-5356  Technology       Phones
# 3    Germany  ...  TEC-PH-5267  Technology       Phones
# 4    Senegal  ...  TEC-CO-6011  Technology      Copiers
# 5  Australia  ...  TEC-PH-5842  Technology       Phones
#
#                                 Product Name Sales Quantity  Discount  Profit  \
# 1  Novimex Executive Leather Armchair, Black  3709        9       0.1     288
# 2          Nokia Smart Phone, with Caller ID  5175        9       0.1     919
# 3             Motorola Smart Phone, Cordless  2892        5       0.1      96
# 4             Sharp Wireless Fax, High-Speed  2832        8       0.0     311
# 5        Samsung Smart Phone, with Caller ID  2862        5       0.1     763
#
#    Shipping Cost  Order Priority
# 1         923.63        Critical
# 2         915.49          Medium
# 3         910.16          Medium
# 4         903.04        Critical
# 5         897.35        Critical
#
# [5 rows x 22 columns]

# %%
len(shipping_g500)
# Out:
# 120

# %%
shipping_g500.shape
# Out:
# (120, 22)

# %%
# Count the number of segments, countries, regions, markets, categories, and sub-categories present in the global_superstore_2016 data.

# %%
global_data['Segment'].value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: Segment, dtype: int64

# %%
len(global_data['Country'].value_counts())
# Out:
# 165

# %%
print(global_data['Region'].value_counts())
print(len(global_data['Region'].value_counts()))
# Out:
# Western Europe       5883
# Central America      5616
# Oceania              3487
# Western US           3203
# Southeastern Asia    3129
# South America        2988
# Eastern US           2848
# Southern Asia        2655
# Western Asia         2440
# Eastern Asia         2374
# Central US           2323
# Northern Europe      2204
# Southern Europe      2113
# Caribbean            1690
# Southern US          1620
# Eastern Europe       1529
# Western Africa       1460
# North Africa         1278
# Eastern Africa        728
# Central Africa        643
# Southern Africa       478
# Canada                384
# Central Asia          217
# Name: Region, dtype: int64
# 23

# %%
global_data['Market'].value_counts()
# Out:
# Asia Pacific    14302
# Europe          11729
# USCA            10378
# LATAM           10294
# Africa           4587
# Name: Market, dtype: int64

# %%
global_data['Category'].value_counts()
# Out:
# Office Supplies    31289
# Technology         10141
# Furniture           9860
# Name: Category, dtype: int64

# %%
global_data['Sub-Category'].value_counts()
# Out:
# Binders        6146
# Storage        5049
# Art            4864
# Paper          3492
# Chairs         3434
# Phones         3357
# Furnishings    3154
# Accessories    3075
# Fasteners      2601
# Labels         2601
# Bookcases      2411
# Supplies       2407
# Envelopes      2387
# Copiers        2223
# Appliances     1742
# Machines       1486
# Tables          861
# Name: Sub-Category, dtype: int64

# %% [markdown]
# 3: Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' after paying the Shipping Cost more than 500.

# %%
cond_country_india = (global_data['Country'] == 'India') & (global_data['Category'] == 'Technology') & (global_data['Shipping Cost'] >= 500)

# %%
Indian_OrderID = global_data[cond_country_india]

# %%
Indian_Order_IDs = Indian_OrderID['Order ID'].tolist()
Indian_Order_IDs
# Out:
# ['IN-2015-BF1100558-42319',
#  'IN-2015-SW2027558-42125',
#  'IN-2013-SG2047058-41424',
#  'IN-2013-GP1474058-41419']

# %% [markdown]
# 4 : Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' the Sales greater than 500.

# %%
Indian_sales = (global_data['Country'] == 'India') & (global_data['Category'] == 'Technology') & (global_data['Sales'] >= 500)
Indian_sales_df = global_data[Indian_sales]

# %%
Indian_Sales_IDs = Indian_sales_df['Order ID'].tolist()
Indian_Sales_IDs[:20]
# Out:
# ['IN-2015-BF1100558-42319',
#  'IN-2015-SW2027558-42125',
#  'IN-2013-SG2047058-41424',
#  'IN-2013-GP1474058-41419',
#  'IN-2014-SV2081558-41968',
#  'IN-2015-AP1072058-42284',
#  'IN-2015-CR1282058-42294',
#  'IN-2012-AB1010558-41270',
#  'IN-2014-CA1277558-41802',
#  'IN-2015-AF1088558-42222',
#  'IN-2012-CL1270058-41226',
#  'IN-2012-MG1820558-40962',
#  'IN-2015-CY1274558-42300',
#  'IN-2014-MR1754558-41954',
#  'IN-2015-CC1247558-42129',
#  'IN-2013-NZ1856558-41398',
#  'IN-2012-DM1352558-41123',
#  'IN-2013-DL1333058-41328',
#  'IN-2013-BW1111058-41404',
#  'IN-2014-JE1561058-41895']

# %%
# How many people from the State 'Karnataka' have bought the things under the category 'Technology'?

# %%
cond_states = (global_data['Country']=='India') & (global_data['Category'] =='Technology')
global_data_states = global_data[cond_states]

# %%
len(global_data_states[global_data_states['State']=='Karnataka'])
# Out:
# 21

# %% [markdown]
# 6. Get the list of countries where the 'Profit' and 'Shipping Cost's are greater than or equal to 2000 and 300 respectively

# %%
cond1 = (global_data['Profit'] >= 2000) & (global_data['Shipping Cost'] >= 300)
global_data_country = global_data[cond1]

# %%
global_data_country[:5]
# Out:
#                      Order ID Order_Date  Ship_Date       Ship Mode  \
# 17    ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  Standard Class
# 42    IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 81     MO-2015-DP310586-42305 2015-10-28 2015-10-30    Second Class
# 109   IT-2014-VM2168591-41711 2014-03-13 2014-03-13        Same Day
# 192  ES-2014-JG15160139-41660 2014-01-21 2014-01-24    Second Class
#
#        Customer Name      Segment  Postal Code                City  \
# 17     Patrick Jones    Corporate          NaN               Prato
# 42       Vivek Grady    Corporate          NaN  Thiruvananthapuram
# 81      Dave Poirier    Corporate          NaN              Meknes
# 109  Valerie Mitchum  Home Office          NaN      Bergen op Zoom
# 192     James Galang     Consumer          NaN    Stockton-on-Tees
#
#                 State         Country  ...   Product ID         Category  \
# 17            Tuscany           Italy  ...  OFF-AP-4743  Office Supplies
# 42             Kerala           India  ...  FUR-BO-5951        Furniture
# 81   Meknès-Tafilalet         Morocco  ...  TEC-CO-3710       Technology
# 109     North Brabant     Netherlands  ...  FUR-CH-5442        Furniture
# 192           England  United Kingdom  ...  FUR-TA-3344        Furniture
#
#     Sub-Category                                   Product Name Sales  \
# 17    Appliances                              Hoover Stove, Red  7958
# 42     Bookcases           Sauder Classic Bookcase, Traditional  5667
# 81       Copiers                      Canon Wireless Fax, Laser  5301
# 109       Chairs  Office Star Executive Leather Armchair, Black  2570
# 192       Tables     Barricks Conference Table, Fully Assembled  5451
#
#     Quantity  Discount  Profit  Shipping Cost  Order Priority
# 17        14       0.0    3979         778.32             Low
# 42        13       0.0    2097         658.35          Medium
# 81        14       0.0    2597         568.45          Medium
# 109       11       0.5    2211         520.89            High
# 192        6       0.0    2071         432.13          Medium
#
# [5 rows x 22 columns]

# %%
global_data_country['Country']
# Out:
# 17                Italy
# 42                India
# 81              Morocco
# 109         Netherlands
# 192      United Kingdom
# 215               Japan
# 245           Lithuania
# 313               India
# 334           Australia
# 362            Pakistan
# 419       United States
# 2257      United States
# 6422      United States
# 11123     United States
# 11755     United States
# 23110     United States
# 24214     United States
# 25238     United States
# 31453     United States
# 32753     United States
# 46295     United States
# 49003     United States
# 49968     United States
# Name: Country, dtype: object

# %%
listOf_Countries = global_data_country['Country'].drop_duplicates().tolist()
listOf_Countries
# Out:
# ['Italy',
#  'India',
#  'Morocco',
#  'Netherlands',
#  'United Kingdom',
#  'Japan',
#  'Lithuania',
#  'Australia',
#  'Pakistan',
#  'United States']

# %% [markdown]
# 7. Find the list of Indian states where the people have purchased the things under the category Technology.

# %%
cond2 = (global_data['Country']=='India') & (global_data['Category']=='Technology')
global_data_Indians = global_data[cond2]

# %%
global_data_Indians
# Out:
#                       Order ID Order_Date  Ship_Date       Ship Mode  \
# 41     IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 48     IN-2015-SW2027558-42125 2015-05-01 2015-05-01        Same Day
# 55     IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
# 90     IN-2013-GP1474058-41419 2013-05-25 2013-05-28    Second Class
# 130    IN-2014-SV2081558-41968 2014-11-25 2014-11-27     First Class
# ...                        ...        ...        ...             ...
# 39631  IN-2013-JR1570058-41441 2013-06-16 2013-06-22  Standard Class
# 40262  IN-2014-GZ1447058-41721 2014-03-23 2014-03-27  Standard Class
# 42345  IN-2015-CR1282058-42294 2015-10-17 2015-10-21  Standard Class
# 43976  IN-2015-LD1700558-42101 2015-04-07 2015-04-11  Standard Class
# 51172  IN-2014-AS1013558-41817 2014-06-27 2014-07-03  Standard Class
#
#           Customer Name      Segment  Postal Code        City           State  \
# 41          Barry Franz  Home Office          NaN   Gorakhpur         Haryana
# 48     Scott Williamson     Consumer          NaN  Jamshedpur       Jharkhand
# 55         Sheri Gordon     Consumer          NaN      Bhopal  Madhya Pradesh
# 90          Guy Phonely    Corporate          NaN       Delhi           Delhi
# 130          Stuart Van    Corporate          NaN    Vadodara         Gujarat
# ...                 ...          ...          ...         ...             ...
# 39631    Jocasta Rupert     Consumer          NaN      Kollam          Kerala
# 40262     Gary Zandusky     Consumer          NaN    Ludhiana          Punjab
# 42345       Cyra Reiten  Home Office          NaN       Patna           Bihar
# 43976    Lisa DeCherney     Consumer          NaN  Kukatpalli       Telangana
# 51172      Adrian Shami  Home Office          NaN   Nagercoil      Tamil Nadu
#
#       Country  ...   Product ID    Category Sub-Category  \
# 41      India  ...  TEC-PH-5269  Technology       Phones
# 48      India  ...  TEC-MA-5007  Technology     Machines
# 55      India  ...  TEC-CO-4590  Technology      Copiers
# 90      India  ...  TEC-PH-5356  Technology       Phones
# 130     India  ...  TEC-CO-4577  Technology      Copiers
# ...       ...  ...          ...         ...          ...
# 39631   India  ...  TEC-AC-4178  Technology  Accessories
# 40262   India  ...  TEC-AC-5221  Technology  Accessories
# 42345   India  ...  TEC-PH-5838  Technology       Phones
# 43976   India  ...  TEC-CO-3591  Technology      Copiers
# 51172   India  ...  TEC-AC-3388  Technology  Accessories
#
#                                  Product Name Sales Quantity  Discount  \
# 41       Motorola Smart Phone, with Caller ID  4518        7       0.0
# 48                       Konica Inkjet, White  2174        7       0.0
# 55                Hewlett Wireless Fax, Color  1526        4       0.0
# 90          Nokia Smart Phone, with Caller ID  1916        3       0.0
# 130           Hewlett Fax Machine, High-Speed  1590        5       0.0
# ...                                       ...   ...      ...       ...
# 39631       Enermax Numeric Keypad, Bluetooth   114        2       0.0
# 40262       Memorex Numeric Keypad, Erganomic    93        2       0.0
# 42345  Samsung Signal Booster, with Caller ID   136        1       0.0
# 43976           Brother Fax and Copier, Color   385        2       0.0
# 51172           Belkin Memory Card, Bluetooth   114        1       0.0
#
#        Profit  Shipping Cost  Order Priority
# 41        632         658.69            High
# 48        500         637.86        Critical
# 55        732         625.77        Critical
# 90        498         548.40        Critical
# 130       572         493.20        Critical
# ...       ...            ...             ...
# 39631       4           2.33          Medium
# 40262      42           2.18          Medium
# 42345      57           1.92            High
# 43976      84           1.77          Medium
# 51172      32           1.06          Medium
#
# [354 rows x 22 columns]

# %%
listOf_States = global_data_Indians['State'].drop_duplicates().tolist()
listOf_States
# Out:
# ['Haryana',
#  'Jharkhand',
#  'Madhya Pradesh',
#  'Delhi',
#  'Gujarat',
#  'Bihar',
#  'Kerala',
#  'Chhattisgarh',
#  'Tamil Nadu',
#  'West Bengal',
#  'Maharashtra',
#  'Karnataka',
#  'Rajasthan',
#  'Uttar Pradesh',
#  'Andhra Pradesh',
#  'Telangana',
#  'Odisha',
#  'Punjab',
#  'Assam',
#  'Uttarakhand',
#  'Puducherry',
#  'Jammu and Kashmir']

# %%
len(listOf_States)
# Out:
# 22

# %% [raw]
# 8. Find the overall rank of "India" where the 'Profit' is maximum under the category 'Technology'.

# %%
print('Max Profit:', max(global_data['Profit']))
print('Min Profit:', min(global_data['Profit']))
# Out:
# Max Profit: 8399
# Min Profit: 0

# %%
condition_top_countries = (global_data['Profit'] > 0) & (global_data['Category'] == 'Technology')

# %%
global_countries = global_data[condition_top_countries]

# %%
global_countries.shape
# Out:
# (9915, 22)

# %%
sorted_global_countries = global_countries.sort_values(by=['Profit'], ascending=False)

# %%
sorted_global_countries.head(n=5)
# Out:
#                        Order ID Order_Date  Ship_Date       Ship Mode  \
# 49003  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 44248  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 11755  CA-2014-CS12505140-41969 2014-11-26 2014-12-03  Standard Class
# 25238  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# 6591    TU-2014-DM3345134-41908 2014-09-26 2014-09-26        Same Day
#
#        Customer Name    Segment  Postal Code       City       State  \
# 49003   Tamara Chand  Corporate          NaN  Lafayette     Indiana
# 44248   Raymond Buch   Consumer          NaN    Seattle  Washington
# 11755  Cindy Stewart   Consumer          NaN  Lancaster        Ohio
# 25238   Hunter Lopez   Consumer          NaN     Newark    Delaware
# 6591   Denise Monton  Corporate          NaN    Bornova       Izmir
#
#              Country  ...   Product ID    Category Sub-Category  \
# 49003  United States  ...  TEC-CO-3691  Technology      Copiers
# 44248  United States  ...  TEC-CO-3691  Technology      Copiers
# 11755  United States  ...  TEC-MA-3854  Technology     Machines
# 25238  United States  ...  TEC-CO-3691  Technology      Copiers
# 6591          Turkey  ...  TEC-PH-5267  Technology       Phones
#
#                                     Product Name  Sales Quantity  Discount  \
# 49003      Canon imageCLASS 2200 Advanced Copier  17499        5       0.0
# 44248      Canon imageCLASS 2200 Advanced Copier  13999        4       0.0
# 11755  Cubify CubeX 3D Printer Double Head Print   4499        5       0.7
# 25238      Canon imageCLASS 2200 Advanced Copier  10499        3       0.0
# 6591              Motorola Smart Phone, Cordless   3085       12       0.6
#
#        Profit  Shipping Cost  Order Priority
# 49003    8399      349.07000          Medium
# 44248    6719       20.00054          Medium
# 11755    6599      451.63000             Low
# 25238    5039      363.19000          Medium
# 6591     4088       51.89000        Critical
#
# [5 rows x 22 columns]

# %%
sorted_global_countries['Country']
# Out:
# 49003    United States
# 44248    United States
# 11755    United States
# 25238    United States
# 6591            Turkey
#              ...
# 45055    United States
# 46466        Venezuela
# 31893    United States
# 30799           Russia
# 41207             Iraq
# Name: Country, Length: 9915, dtype: object

# %%
listOf_Countires_Top_Profit = sorted_global_countries['Country'].drop_duplicates().tolist()
listOf_Countires_Top_Profit
# Out:
# ['United States',
#  'Turkey',
#  'Pakistan',
#  'Japan',
#  'India',
#  'Morocco',
#  'United Kingdom',
#  'New Zealand',
#  'Brazil',
#  'Germany',
#  'Netherlands',
#  'China',
#  'Senegal',
#  'Democratic Republic of the Congo',
#  'France',
#  'Iran',
#  'Italy',
#  'Spain',
#  "Cote d'Ivoire",
#  'Guatemala',
#  'Lithuania',
#  'Canada',
#  'Saudi Arabia',
#  'Bangladesh',
#  'Australia',
#  'South Korea',
#  'Switzerland',
#  'Mexico',
#  'Nigeria',
#  'Nicaragua',
#  'El Salvador',
#  'Russia',
#  'Thailand',
#  'Indonesia',
#  'Cuba',
#  'Belgium',
#  'Kazakhstan',
#  'Lesotho',
#  'Cameroon',
#  'Austria',
#  'South Africa',
#  'Mauritania',
#  'Qatar',
#  'Yemen',
#  'Egypt',
#  'Burkina Faso',
#  'Iraq',
#  'Vietnam',
#  'Portugal',
#  'Dominican Republic',
#  'Malaysia',
#  'Madagascar',
#  'Ghana',
#  'Honduras',
#  'Mozambique',
#  'Angola',
#  'Ukraine',
#  'Algeria',
#  'Denmark',
#  'Belarus',
#  'Afghanistan',
#  'Panama',
#  'Norway',
#  'Ecuador',
#  'Liberia',
#  'Venezuela',
#  'Philippines',
#  'Colombia',
#  'Cambodia',
#  'Ireland',
#  'Namibia',
#  'Argentina',
#  'Chile',
#  'Georgia',
#  'Greece',
#  'Singapore',
#  'Zambia',
#  'Kenya',
#  'Sweden',
#  'Barbados',
#  'Azerbaijan',
#  'Zimbabwe',
#  'Uzbekistan',
#  'Poland',
#  'Romania',
#  'Trinidad and Tobago',
#  'Bolivia',
#  'Guyana',
#  'Hungary',
#  'Tanzania',
#  'Nepal',
#  'Peru',
#  'Bosnia and Herzegovina',
#  'Central African Republic',
#  'Israel',
#  'Benin',
#  'Estonia',
#  'Bulgaria',
#  'Somalia',
#  'Rwanda',
#  'Serbia',
#  'Albania',
#  'Syria',
#  'Turkmenistan',
#  'Tajikistan',
#  'Guinea-Bissau',
#  'Mali',
#  'Haiti',
#  'Czech Republic',
#  'Papua New Guinea',
#  'Kyrgyzstan',
#  'Niger',
#  'Gabon',
#  'Finland',
#  'Sudan',
#  'Uganda',
#  'Myanmar (Burma)',
#  'Uruguay',
#  'Croatia',
#  'South Sudan',
#  'Costa Rica',
#  'Hong Kong',
#  'United Arab Emirates',
#  'Mongolia',
#  'Jamaica',
#  'Lebanon',
#  'Tunisia',
#  'Moldova',
#  'Libya',
#  'Paraguay',
#  'Djibouti',
#  'Guadeloupe',
#  'Eritrea',
#  'Jordan',
#  'Taiwan',
#  'Sierra Leone',
#  'Martinique',
#  'Guinea',
#  'Ethiopia',
#  'Equatorial Guinea',
#  'Togo',
#  'Swaziland',
#  'Luxembourg',
#  'Sri Lanka',
#  'Bahrain']

# %%
ranked_data = sorted_global_countries['Country'].drop_duplicates().rank(ascending=False, method='average' )
ranked_data
# Out:
# 49003      8.0
# 6591      14.0
# 362       49.0
# 215       79.0
# 313       87.0
#          ...
# 19592     17.0
# 29037     25.0
# 29689     69.0
# 33381     27.0
# 5060     137.0
# Name: Country, Length: 145, dtype: float64

# %%
ranked_countries = sorted_global_countries['Country'].drop_duplicates()

# %%
ranked_series = pd.concat([ranked_countries, ranked_data], axis=1)
ranked_series
# Out:
#              Country  Country
# 49003  United States      8.0
# 6591          Turkey     14.0
# 362         Pakistan     49.0
# 215            Japan     79.0
# 313            India     87.0
# ...              ...      ...
# 19592           Togo     17.0
# 29037      Swaziland     25.0
# 29689     Luxembourg     69.0
# 33381      Sri Lanka     27.0
# 5060         Bahrain    137.0
#
# [145 rows x 2 columns]

# %% [markdown]
# 9. Display the data with min, max, average and std of 'Profit' & 'Sales' for each Sub-Category under each Category

# %%
grouped_data = global_data.groupby(by=['Country', 'Category', 'Sub-Category'], as_index=True)
grouped_data

# %%
functions = [('min_value', 'min'), ('max_value', 'max'), ('mean_value','mean'), ('std_value', 'std')]

# %%
grouped_data['Sales', 'Profit'].agg(functions)
# Out:
# <ipython-input-110-7e26e9913404>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_data['Sales', 'Profit'].agg(functions)
#                                              Sales                         \
#                                          min_value max_value   mean_value
# Country     Category        Sub-Category
# Afghanistan Furniture       Bookcases          731      2070  1400.500000
#                             Chairs             417       914   665.500000
#                             Furnishings         84       219   134.500000
#                             Tables             267      4626  2113.333333
#             Office Supplies Appliances         669       669   669.000000
# ...                                            ...       ...          ...
# Zimbabwe    Office Supplies Supplies            10        66    37.833333
#             Technology      Accessories         77        77    77.000000
#                             Copiers            154       444   299.000000
#                             Machines            14       104    52.500000
#                             Phones              21       101    61.000000
#
#                                                          Profit            \
#                                             std_value min_value max_value
# Country     Category        Sub-Category
# Afghanistan Furniture       Bookcases      946.815980       102       848
#                             Chairs         351.432070        45       356
#                             Furnishings     51.251341         1        79
#                             Tables        2254.599817        34       647
#             Office Supplies Appliances            NaN       280       280
# ...                                               ...       ...       ...
# Zimbabwe    Office Supplies Supplies        25.031314        12        55
#             Technology      Accessories           NaN        59        59
#                             Copiers        205.060967       257       371
#                             Machines        42.696604        20       173
#                             Phones          56.568542        47       169
#
#
#                                           mean_value   std_value
# Country     Category        Sub-Category
# Afghanistan Furniture       Bookcases     475.000000  527.501659
#                             Chairs        200.500000  219.910209
#                             Furnishings    32.333333   32.240761
#                             Tables        415.000000  332.555259
#             Office Supplies Appliances    280.000000         NaN
# ...                                              ...         ...
# Zimbabwe    Office Supplies Supplies       37.166667   15.917496
#             Technology      Accessories    59.000000         NaN
#                             Copiers       314.000000   80.610173
#                             Machines       76.500000   72.958893
#                             Phones        108.000000   86.267027
#
# [2009 rows x 8 columns]
